# %%
print("Inferences: Capomulin and Ramicane seemed to be the most effective in consistently combating tumor volume. Also, although more mice were treated with these two drug regimens they contained the lowest varience. Lastly with a nearly balanced number of both male and female mice in the study it is hard to say if sex played any role in treatment response")
# Out:
# Inferences: Capomulin and Ramicane seemed to be the most effective in consistently combating tumor volume. Also, although more mice were treated with these two drug regimens they contained the lowest varience. Lastly with a nearly balanced number of both male and female mice in the study it is hard to say if sex played any role in treatment response

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(study_results, mouse_metadata, on="Mouse ID", how='outer')

# Display the data table for preview
merge_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
#Number of unique mice
merge_df["Mouse ID"].nunique()
# Out:
# 249

# %%
#sort data by timepoint
sorted_df=merge_df.sort_values(['Timepoint','Mouse ID']).reset_index()
sorted_df=sorted_df.drop(['index'], axis=1)
#Duplicate mouse id data
duplicate_df=sorted_df[sorted_df.duplicated(['Mouse ID','Timepoint'],keep=False)]
duplicate_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 72      g989          0           45.000000                 0     Propriva
# 73      g989          0           45.000000                 0     Propriva
# 319     g989          5           48.786801                 0     Propriva
# 320     g989          5           47.570392                 0     Propriva
# 554     g989         10           51.745156                 0     Propriva
# 555     g989         10           49.880528                 0     Propriva
# 775     g989         15           51.325852                 1     Propriva
# 776     g989         15           53.442020                 0     Propriva
# 979     g989         20           55.326122                 1     Propriva
# 980     g989         20           54.657650                 1     Propriva
#
#         Sex  Age_months  Weight (g)
# 72   Female          21          26
# 73   Female          21          26
# ...

# %%
#delete Mouse g989
cleaned_df=sorted_df.drop(sorted_df[sorted_df['Mouse ID']=="g989"].index)
cleaned_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a203          0                45.0                 0    Infubinol
# 1     a251          0                45.0                 0    Infubinol
# 2     a262          0                45.0                 0      Placebo
# 3     a275          0                45.0                 0     Ceftamin
# 4     a366          0                45.0                 0     Stelasyn
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          23
# 1  Female          21          25
# 2  Female          17          29
# 3  Female          20          28
# 4  Female          16          29

# %%
#Check for new number of mice
cleaned_df["Mouse ID"].nunique()
# Out:
# 248

# %%
#group by Drug Regimen
grouped_df=cleaned_df.groupby(cleaned_df['Drug Regimen'])
#pandas descibe
regimen_info1=grouped_df['Tumor Volume (mm3)'].describe()
#median
#median=grouped_df['Tumor Volume (mm3)'].median()
#variance
var = grouped_df['Tumor Volume (mm3)'].var(ddof=1)
#standard error of the mean
sem=grouped_df['Tumor Volume (mm3)'].sem()

#combined table
regimen_info=pd.merge(regimen_info1, var, on="Drug Regimen")
regimen_info=pd.merge(regimen_info, sem, on="Drug Regimen")
#delete columns
regimen_info = regimen_info.drop(columns=['count','min','25%','75%','max'])
#rename
regimen_info=regimen_info.rename(columns={"50%":"median",
                                          "Tumor Volume (mm3)_x":"var",
                                          "Tumor Volume (mm3)_y":"sem"})
#reorder
regimen_info=regimen_info[["mean","median","var","std","sem"]]
regimen_info
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
#create new df
drug_regimen_use=cleaned_df["Drug Regimen"].value_counts()
drug_regimen_use_df=pd.DataFrame(drug_regimen_use)
drug_regimen_use_df=drug_regimen_use_df.reset_index()
drug_regimen_use_df=drug_regimen_use_df.rename(columns={'index':'Drug Regimen',
                                              'Drug Regimen':'count'})
#make bar chart
drug_regimen_use_df.plot.bar(x='Drug Regimen',y='count')

#format
plt.ylim(0, max(drug_regimen_use_df['count'])+20)
plt.title("Number of Mice on Each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Unique Mice Tested")
# Out:
# Text(0, 0.5, 'Number of Unique Mice Tested')

# %%
#create lists
count=drug_regimen_use_df['count'].tolist()
regimens=drug_regimen_use_df['Drug Regimen'].tolist()

#create chart
plt.bar(regimens,count,color='b', alpha=0.5, align="center")

#format
plt.title("Number of Mice on Each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Unique Mice Tested")
plt.xticks(rotation=90)

plt.show()

# %%
#create new dataframe
m_or_f_df=cleaned_df['Sex'].value_counts()
m_or_f_df=pd.DataFrame(m_or_f_df)

#make pie chart
m_or_f_df.plot.pie(y='Sex', figsize=(5, 5),title="Male vs Female Mice in Study",)
# Out:
# <AxesSubplot:title={'center':'Male vs Female Mice in Study'}, ylabel='Sex'>

# %%
#create lists
new_df=m_or_f_df.reset_index()
labels=new_df['index'].tolist()
sex=new_df['Sex'].tolist()

#make pie chart
plt.pie(sex, labels=labels,
        autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7f82b5fd0610>,
# ...
#  [Text(-0.03308201408261547, 1.0995024239828841, 'Male'),
#   Text(0.033082014082615095, -1.0995024239828841, 'Female')],
#  [Text(-0.01804473495415389, 0.5997285948997549, '51.0%'),
#   Text(0.018044734954153686, -0.5997285948997549, '49.0%')])

# %%
#create list for regimens
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

#set dataframe to final timepoint and proper regimens
final_state_df=cleaned_df.drop_duplicates(subset='Mouse ID',keep='last',ignore_index=True)
final_state_df=final_state_df.loc[final_state_df['Drug Regimen'].isin(treatment_list)]
final_state_df.groupby(by=['Drug Regimen'],)
final_state_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b447          0           45.000000                 0     Ceftamin
# 7       t573          0           45.000000                 0     Ceftamin
# 8       u153          0           45.000000                 0     Ceftamin
# 10      x226          0           45.000000                 0     Ceftamin
# 12      c326          5           36.321346                 0    Infubinol
# ..       ...        ...                 ...               ...          ...
# 241     y769         45           68.594745                 4     Ceftamin
# 242     y793         45           31.896238                 2    Capomulin
# 243     y865         45           64.729837                 3     Ceftamin
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
tumor_vol_list = final_state_df['Tumor Volume (mm3)'].tolist()

# %%
#get info for Capomulin

Capomulin_results=final_state_df.loc[final_state_df['Drug Regimen']=='Capomulin',['Tumor Volume (mm3)']]
Capomulin_results2=Capomulin_results['Tumor Volume (mm3)']
cap_quartiles = Capomulin_results2.quantile([.25,.5,.75])
cap_lowerq = cap_quartiles[0.25]
cap_upperq = cap_quartiles[0.75]
cap_iqr = cap_upperq-cap_lowerq

#outliers
cap_lower_bound = cap_lowerq - (1.5*cap_iqr)
cap_upper_bound = cap_upperq + (1.5*cap_iqr)

Capomulin_results_list=Capomulin_results2.tolist()
cap_outliers=[]
for volume in Capomulin_results_list:
    if volume > cap_upper_bound:
        cap_outliers.append(volume)
    elif volume < cap_lower_bound:
        cap_outliers.append(volume)
print(f"Capomulin's potential outliers: {cap_outliers}")
# Out:
# Capomulin's potential outliers: []

# %%
Ramicane_results=final_state_df.loc[final_state_df['Drug Regimen']=='Ramicane',['Tumor Volume (mm3)']]
Ramicane_results=Ramicane_results['Tumor Volume (mm3)']
ram_quartiles = Ramicane_results.quantile([.25,.5,.75])
ram_lowerq = ram_quartiles[0.25]
ram_upperq = ram_quartiles[0.75]
ram_iqr = ram_upperq-ram_lowerq

#outliers
ram_lower_bound =ram_lowerq - (1.5*ram_iqr)
ram_upper_bound = ram_upperq + (1.5*ram_iqr)

Ramicane_results=Ramicane_results.tolist()
ram_outliers=[]
for volume in Ramicane_results:
    if volume > ram_upper_bound:
        ram_outliers.append(volume)
    elif volume < ram_lower_bound:
        ram_outliers.append(volume)
print(f"Ramicane's potential outliers: {ram_outliers}")
# Out:
# Ramicane's potential outliers: []

# %%
Infubinol_results=final_state_df.loc[final_state_df['Drug Regimen']=='Infubinol',['Tumor Volume (mm3)']]
Infubinol_results=Infubinol_results['Tumor Volume (mm3)']
inf_quartiles = Infubinol_results.quantile([.25,.5,.75])
inf_lowerq = inf_quartiles[0.25]
inf_upperq = inf_quartiles[0.75]
inf_iqr = inf_upperq-inf_lowerq

#outliers
inf_lower_bound =inf_lowerq - (1.5*inf_iqr)
inf_upper_bound = inf_upperq + (1.5*inf_iqr)

Infubinol_results=Infubinol_results.tolist()
inf_outliers=[]
for volume in Infubinol_results:
    if volume > inf_upper_bound:
        inf_outliers.append(volume)
    elif volume < inf_lower_bound:
        inf_outliers.append(volume)
print(f"Infubinol's potential outliers: {inf_outliers}")
# Out:
# Infubinol's potential outliers: [36.3213458]

# %%
Ceftamin_results=final_state_df.loc[final_state_df['Drug Regimen']=='Ceftamin',['Tumor Volume (mm3)']]
Ceftamin_results=Ceftamin_results['Tumor Volume (mm3)']
cef_quartiles = Ceftamin_results.quantile([.25,.5,.75])
cef_lowerq = cef_quartiles[0.25]
cef_upperq = cef_quartiles[0.75]
cef_iqr = cef_upperq-inf_lowerq

#outliers
cef_lower_bound =cef_lowerq - (1.5*inf_iqr)
cef_upper_bound = cef_upperq + (1.5*inf_iqr)

Ceftamin_results=Ceftamin_results.tolist()
cef_outliers=[]
for volume in Ceftamin_results:
    if volume > cef_upper_bound:
        cef_outliers.append(volume)
    elif volume < cef_lower_bound:
        cef_outliers.append(volume)
print(f"Ceftamin's potential outliers: {cef_outliers}")
# Out:
# Ceftamin's potential outliers: []

# %%
print(f"Capomulin's potential outliers: {cap_outliers}")
print(f"Ceftamin's potential outliers: {cef_outliers}") 
print(f"Infubinol's potential outliers: {inf_outliers}") 
print(f"Ramicane's potential outliers: {ram_outliers}")
# Out:
# Capomulin's potential outliers: []
# Ceftamin's potential outliers: []
# Infubinol's potential outliers: [36.3213458]
# Ramicane's potential outliers: []

# %%
#create box plot group

tumor_size_df= final_state_df[['Tumor Volume (mm3)','Drug Regimen']]
treatment_groups=tumor_size_df.groupby(by='Drug Regimen')

# %%
#create box plot
red_circle = dict(markerfacecolor='r', marker='o')
plot=treatment_groups.boxplot(subplots=False, rot=90, grid=False, flierprops=red_circle)
plot.set_ylabel('Final Tumor Volume (mm3)')

plot
# Out:
# <AxesSubplot:ylabel='Final Tumor Volume (mm3)'>

# %%
#collect and clean mouse data
mouse_l509=cleaned_df.loc[cleaned_df[cleaned_df['Mouse ID']=="l509"].index]
#mouse_l509=mouse_l509.set_index('Timepoint')
mouse_l509_tumor=mouse_l509[['Tumor Volume (mm3)','Timepoint']]
mouse_l509_tumor.reset_index(drop=True)
# Out:
#    Tumor Volume (mm3)  Timepoint
# 0           45.000000          0
# 1           45.851193          5
# 2           46.759074         10
# 3           47.488599         15
# 4           48.070452         20
# 5           44.006257         25
# 6           44.708055         30
# 7           40.207288         35
# 8           40.770813         40
# 9           41.483008         45

# %%
mouse_plot=plt.plot(mouse_l509_tumor['Timepoint'], mouse_l509_tumor['Tumor Volume (mm3)'], color="blue", label="Mouse l509")
plt.legend(handles=mouse_plot, loc="best")

plt.title("Capomulin Treatment of Mouse l509")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
results=cleaned_df.loc[cleaned_df['Drug Regimen']=='Capomulin',:]
averages=results.groupby(by='Mouse ID').mean()
mouse_weight=averages[['Tumor Volume (mm3)','Weight (g)']]
mouse_weight.reset_index(drop=True)
# Out:
#     Tumor Volume (mm3)  Weight (g)
# 0            41.963636        22.0
# 1            40.083699        21.0
# 2            36.505973        17.0
# 3            41.990097        19.0
# 4            44.613344        22.0
# 5            44.805810        24.0
# 6            39.141053        20.0
# 7            44.465236        23.0
# 8            43.216925        21.0
# 9            44.434474        21.0
# 10           42.507261        19.0
# 11           34.847470        17.0
# 12           39.049816        19.0
# 13           45.798970        25.0
# 14           36.509212        17.0
# 15           43.367364        25.0
# 16           34.559143        17.0
# 17           42.803733        23.0
# 18           39.328725        17.0
# 19           39.887495        17.0
# 20           41.581595        21.0
# 21           41.384825        23.0
# 22           41.352452        21.0
# 23           36.182040        15.0
# 24           38.506829        17.0

# %%
plt.scatter(mouse_weight["Weight (g)"],mouse_weight["Tumor Volume (mm3)"])
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()

# %%
from scipy.stats import linregress

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(mouse_weight["Weight (g)"],mouse_weight["Tumor Volume (mm3)"])
regress_values = mouse_weight["Weight (g)"] * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(mouse_weight["Weight (g)"],mouse_weight["Tumor Volume (mm3)"])
plt.plot(mouse_weight["Weight (g)"],regress_values,"r-")
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
correlation = mouse_weight["Weight (g)"]. corr(mouse_weight["Tumor Volume (mm3)"])
print(f"The correlation between mouse weight and the average tumor volume is {correlation}")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.8419363424694717
